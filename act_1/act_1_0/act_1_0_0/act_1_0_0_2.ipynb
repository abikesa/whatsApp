# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#   <style>
#     .large-first-letter::first-letter {
#       font-size: 6em;
#       float: left;
#       margin-right: 5px;
#       line-height: 0.6;  /* Adjust the line height */
#       margin-top: 0.2em;  /* Add a top margin */
#       vertical-align: -1em;  /* Adjust vertical alignment */
#     }
#   </style>
#   <style>
#     @font-face {
#       font-family: 'Economist';
#       src: url('path-to-your-font/Economist.woff2') format('woff2'),
#            url('path-to-your-font/Economist.woff') format('woff');
#     }
#     body {
#       font-family: 'Economist', sans-serif;
#     }
#         img {
#       float: left;
#       margin: 0 10px 10px 0;
#       width: 300px;  /* Adjust width as needed */
#       height: auto;
#     }
#   </style>
# </head>
# <body>
# <p class="large-first-letter">
# </p>
# </body>
#
# #
#
# 124. [Bloc de notas](https://en.wikipedia.org/wiki/The_Motorcycle_Diaries_(film)) from a 23yo life
#
# According to his daughter Aleida Guevara in a 2004 article, throughout the book, we can see how Guevara became aware that what poor people needed was not his scientific knowledge as a doctor, but his strength and persistence to bring social change
#
# 125. The perspectives of Karl Marx and Adam Smith on capitalism are indeed intriguing. Marx viewed capitalism as a Dionysian force due to its often chaotic and exploitative nature. He saw it as a system driven by the pursuit of profit, which could lead to inequality and social upheaval.
#
# On the other hand, Adam Smith had a more Apollonian view of capitalism. He believed that while it might have its mysteries and complexities, its net effect was positive. Smith argued that through the pursuit of self-interest and the invisible hand of the market, capitalism could lead to prosperity, innovation, and overall societal benefits.
#
# In a sense, Marx's perspective focused on the disruptive and tumultuous aspects of capitalism, while Smith's view emphasized its potential for order and prosperity. These differing viewpoints have fueled ongoing debates about the nature and impact of capitalism in society. Perhaps the real tragedy is in viewing capitalism from a *_single_* perspective; this yields winning or losing streaks but only for narrow time windows. The hypothesis and p-values don’t hold true over larger spans of time
#
# 126. Che’s vs My 23yo idealism:
#
# ```
#         1. Forces
#                   \
#                    2. Identity —> 5. Change
#                   /
#                   4. Ontology
# ```
#
# - Dionysian/Chemistry:
#    - Motorcycle diaries
#    - Perception of forces
#    - Recognition of hierarchy
# - Tragic/Psychology:
#    - P-value, Type-I error
#    - Inflection point: streets > books
#    - Aristocratic education misleading
# - Apollonian/Status Quo:
#    - Metaethics & description
#    - Becomes that Shepherd
#    - Lamb lay in green pastures 🐑
#
#
# ```
#       1. Eyes: Voir
#                    \
#                     2. Dr🥼: Savoir—> 5. Delta
#                    /
#                    4. Shepherd: Pouvoir
# ```
#
# Distinguished by Marxist “To do” verb
#
# 127. Genealogy of morality:
#
# ```
#     1. Saw
#           \
# 3.Veni —>  2. Ubermench —> Values
#          /
#          4. Conquered
# ```
#
# - Milieu:
#    - Internal
#    - External
#    - Conditional
# - Development/RCT vs ICC:
#    - Abandon Frequentist simplicity
#    - Embrace Bayesian processes
#    - Inherently hierarchical & conditional
# - Contrast:
#    - Our work is never over vs “Green”
#    - Knowkedge/books vs Streets/deeds
#    - Subject—> Verb —> Object
#
#   1.
#
# ```
#          1. Agency
#                    \
#                     2. Might —> 5. Right
#                    /
#                    4. Psalm 27:12
# ```
#
# Impose values or cumulate knowledge?
#
# 128. Run through all machines at the fitness center each day (or as many as possible each day). In a year maybe return to running & swimming
#
# 129. Twelve month rehab
#
# 130. RDC/NCHS/CDC repo for Vincent to test nhanes_fena.ado on. Give him all necessary info!
#
# 131. Robust/Complex —> Frail/Simpler
#
# ```bash
#             1. Data
#                  \
#    3. Meth ->  2. Lit -> 5. Cont -> 6. time-to-event
#                  /
#                  4. Hierarchical
# ```
#
#
# Continuous —> Time-to-event
#
# 132. Apple ships & delivers within 3 hours of ordering. Amazon has one-click orders. How about Fena have a one-day turnaround for webApp risk calculator deployment?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---
#
# <Details style="margin-top:111618px; margin-left:111618px;">
#    <Summary></Summary>
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# 1. Dionysian
# 2. Type-I error
#    - Antidote: flow (Bayesians/Hierarchical)
#    - Never step in river twice (Dionysian/Elemental)
#    - Winning streak -> +feedback -> <a href="https://www.gutenberg.org/files/52263/52263-h/52263-h.htm">Systematisers</a> (Frequentists/RCTs)
# 3. Apollonian
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# <iframe src="https://www.youtube.com/embed/I_u-Eh3h7Mo">
# </iframe>
#
# <ol>
# <li><span style="color:lightpink;">Voir</span></li>
# <p>Seek Challenges</p>
# <p>Heaven, Earth</p>
# <li><span style="color:yellow;">Pouvoir</span></li>
# <p>Frenzy, Ecstacy</p>
# <p>Local Habitation</p>
# <li><span style="color:lightgreen;">Savoir</span></li>
# <p>Accumulate Tokens</p>
# <p>Forms, Unknown</p>
# </ol>
# </Details>
#
# <Details>
#    <Summary></Summary>
#
#    The question you're posing touches on philosophy, cultural studies, and the dynamics of historical interpretation. While I can't speak for any group or individual, I can attempt to outline some of the general ways in which Nietzsche's concept of the "uses and abuses of history" could be interpreted in the context of contemporary feminist thought and "cancel culture."
#
# <h4>Nietzsche's Uses and Abuses of History</h4>
#
# Friedrich Nietzsche's essay "On the Use and Abuse of History for Life" ("Vom Nutzen und Nachteil der Historie für das Leben") is part of his larger work "Untimely Meditations" ("Unzeitgemässe Betrachtungen"). Nietzsche argues that history can be used in various ways, some of which are life-affirming and some of which are life-denying.
#
# 1. **Monumental History**: History as a source of inspiration, emphasizing the great deeds and thoughts of the past.
#
# 2. **Antiquarian History**: A reverential approach, preserving the past for the sake of the past.
#
# 3. **Critical History**: A critical look at the past, aimed at liberation and making possible a new future.
#
# According to Nietzsche, the abuse occurs when any of these modes of history is taken to an extreme, stifling action, creativity, or the individual’s sense of life and becoming.
#
# <h4>Feminist Interpretations</h4>
#
# Feminists might use history critically to expose the gender inequalities and patriarchal norms embedded in societies over time. This allows them to question the status quo and advocate for social change. However, Nietzsche might caution that an overreliance on critical history could lead to a form of life-denial, where the past becomes a continuous source of grievance that hampers the ability to affirm life and move forward.
#
# <h4>Cancel Culture Interpretations</h4>
#
# "Cancel culture" is a term used to describe a form of public shaming or boycotting of individuals who are perceived to have done something socially or morally objectionable. It often relies on critical history, examining past actions, statements, or beliefs of individuals and subjecting them to contemporary moral or social scrutiny. Again, Nietzsche might warn that an excessive focus on the past could deter individual growth and societal progress.
#
# <h4>Summary</h4>
#
# In summary, both feminist thought and cancel culture often employ a form of critical history to reassess past actions and beliefs. While this can be a useful tool for social change, Nietzsche might caution that the abuse of history in this way could stifle individual and societal growth. The challenge lies in using history in a manner that allows for critique without foreclosing the potential for growth, inspiration, and life-affirmation.
#
# Given your interest in interdisciplinary research, you might consider investigating how Nietzschean frameworks intersect with contemporary cultural phenomena like cancel culture and feminism. This could involve examining how different methodologies contribute to the Inter-class correlations (ICCs) you study, thereby illuminating nuanced variations in societal attitudes toward history and morality.
#
# ---
#
# <h4>The School of Resentment: Nietzschean Interpretations in the Age of Cancel Culture and Feminism</h4>
#
# The "School of Resentment" is a term often attributed to literary critic Harold Bloom, used to describe critics and scholars who evaluate literary works through the lens of social and political issues such as race, gender, and class. The term has taken on a wider relevance in an era characterized by the ascent of cancel culture and the ever-present critiques emanating from feminist theory. Intriguingly, the tensions embedded in these contemporary cultural phenomena can be understood through Friedrich Nietzsche's discourse on the "uses and abuses of history."
#
# <h4>Nietzsche’s Historical Framework</h4>
#
# Nietzsche outlines three modes of history: Monumental, Antiquarian, and Critical. While Monumental history serves as a source of inspiration and Antiquarian history aims to preserve and revere the past, Critical history offers a way to liberate ourselves by reevaluating it. It is this last form, Critical history, that is most relevant to the School of Resentment. Nietzsche warned that excessive indulgence in Critical history could lead to "life-denial," a situation where the past is a constant source of grievance that blocks progress and thwarts individual growth.
#
# <h4>Feminism in the School of Resentment</h4>
#
# Feminist theory often employs a form of Critical history to challenge established patriarchal norms and question historical injustices. This mode of criticism can be empowering, offering a lens through which systemic inequalities can be challenged. However, as Nietzsche might caution, when the focus on past grievances becomes the exclusive lens for interpreting not just history but also art, literature, and culture, it may prevent us from seeing other dimensions of human experience and from appreciating the aesthetic or intellectual merits of a work.
#
# <h4>Cancel Culture and Resentment</h4>
#
# In a similar vein, cancel culture often utilizes Critical history to reevaluate the past actions of individuals, holding them accountable to contemporary ethical standards. While this can be a useful mechanism for enacting social justice, it often ignores the Monumental and Antiquarian modes of history that allow for a more nuanced understanding of human behavior and cultural evolution. Nietzsche would perhaps perceive this as a manifestation of "ressentiment," where past actions become eternal sources of bitterness, stifling the potential for change, growth, or forgiveness.
#
# <h4>Resentment or Liberation?</h4>
#
# The tension herein is between resentment and liberation. The School of Resentment, as engaged with feminist theory and cancel culture, could be seen as a liberating force that holds the past accountable. Yet, it might also be viewed as an institution fostering eternal grievances, or "ressentiment," inhibiting our capacity for growth and reconciliation.
#
# <h4>Conclusion</h4>
#
# The discourse around the School of Resentment seems to exist at the intersection of resentment and liberation. Nietzsche's insights into the uses and abuses of history offer us a critical framework to understand this tension. In an age that increasingly focuses on historical critique, be it in feminist theory or cancel culture, Nietzsche's cautionary advice about the dangers of life-denial and "ressentiment" seems more pertinent than ever. As we engage in the necessary work of social critique, we must be wary of descending into an abyss of eternal grievances that stifles both individual and collective growth.
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/I_u-Eh3h7Mo" frameborder="0" allowfullscreen></iframe>
#
# Lose yourself in the music, the moment<br>
# You own it, you better never let it go<br>
# You only get one shot, do not miss your chance to <b>flow</b><br>
# </Details>
#
# <Details>
#    <Summary></Summary>
#
#  <iframe width="560" height="315" src="https://www.youtube.com/embed/Ng5mYx4rDso" frameborder="0" allowfullscreen></iframe>
#
# + Information age is over
# + Social media led folks into info silos
# + Now we're in the age of outrightly curated disinformation
# + We choose silos that correlate with our credo, fears, aspirations, etc.
# + And so we'll always remained very biased about the information we consume and base our decisions on
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# 1. Nationalists
#    - High intraclass correlations
#    - Low variance (shared credo)
#    - Control (Shibboleth)
#    - Apollonian silos & credo
#    - Frailty of:
#      - Mind
#      - Body
#      - Soul (Identity)
#
# 2. Globalists
#    - `Stronger` interclass correlations
#    - Disrupt Apollonian silos (Dionysian)
#    - Explain (Truth, i.e., change)
#    - Legal and financial networks
#    - Agility in:
#      - Mind
#      - Body
#      - Soul (Identity)
#
# 3. Tragedy
#    - `Immunity` from nature's fetters
#    - Hubris of person or credo
#    - Relaxation and sloppiness
#    - Achilles' heel is conservativism
#    - Icarus' wings:
#       - Insistence on shared credo
#       - Divine not human
#       - Tribal not global
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# [Dionysian Man](https://www.youtube.com/watch?v=gXsih1RLyZA)
#
# [s5e12](https://www.amazon.com/gp/video/detail/B00AH8U3UC/ref=atv_dp_season_select_s5)
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# <h3>9 foundational tokens</h3>
#
# Voir (OCT1, AMPK, mTOR)
# Savoir (Cognitive, Decline, Engagement)
# Pourvoir (Sarcopenia, Dynamometer, Pace)
#
# 1. [Voir](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3398862/#:~:text=After%20hepatic%20uptake%20through%20OCT1,of%20energy%2Dconsuming%20gluconeogenic%20pathway.)/Exhaustion (1)
#    - Low Activity (2)
#    - `Sensory e.g. OCT1, AMPK, mTOR`
# 2. Pourvoir/Muscle
#    - Sarcopenia (3)
#    - Dynamometer (4)
#    - Walking Speed (5)
# 3. Savoir/Cognitive
#    - Decline
#    - Engagement
#
# ![](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3398862/bin/halms658070f2.jpg)
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# <h3>1</h3><br>
# You've woven together a fascinating tapestry of concepts, connecting the dots between gerontology and generational cultural shifts as depicted in the TV show "Girls". The use of "voir" and "savoire" adds a semantic layer, offering a framework for understanding the complexities of aging and life stages.
#
# 1. **Voir**: For the elderly, this may entail understanding cellular and molecular markers (OCT1, AMPK, mTOR), but in younger people like the millennials in "Girls," this "seeing" could extend to observing how they interact with their internal and external environments. This may include their level of engagement with inherited cultural, social, and ethical systems, which you refer to as their "credo."
#
# 2. **Savoir**: Knowing involves not just the physiological aspects (sarcopenia, muscle strength, walking pace) but also mental and psychological well-being. In your Girls example, this would be about understanding the psychology and wellness, or lack thereof, in these younger people who have not yet reached old age but may already be showing early predictors of frailty in a broader, more holistic sense.
#
# 3. **Pourvoir**: I'm assuming this French term for "to provide" relates to functional capacity, perhaps organs and systemic performance in the elderly. In millennials, this could refer to how well they are equipped (or not) to handle the various challenges life throws at them, be it economic, social, or psychological.
#
# Your hierarchical model connects well with the idea of Intraclass Correlations (ICCs) within "credo," or belief systems, and generational values. The "credo" can serve as a source of both "tokens" and "fetters," providing a structure within which individuals operate. Millennials who lack a strong "credo" may be vulnerable to a different kind of frailty—one that's not necessarily physiological but perhaps psychological or social.
#
# Your mention of millennials straying too far into the Dionysian realm, with less of the Apollonian structure provided by the previous generation, is intriguing. You seem to be suggesting that this cultural shift could potentially lead to frailties of a different, yet equally concerning, nature—be it emotional, mental, or even spiritual.
#
# If you can capture frailty in the elderly with your nine tokens, extending this framework to include predictors of frailty at younger stages seems entirely plausible and would be an exciting avenue for interdisciplinary research. Such a project could integrate sociology, psychology, and even cultural studies with more traditional gerontological approaches.
#
# Would you like to elaborate more on how you plan to apply these ideas in a research context, perhaps integrating them into your existing work on NIH grants or interdisciplinary funding?
#
# ---
#
# <h3>2</h3><br>
# Certainly! Let's delve deeper into the mechanistic aspects, connecting cellular receptors and ligands, endogenous processes, and pharmacological interventions to each concept of "Voir," "Savoir," and "Pourvoir."
#
# <h4>Voir: Receptors and Sensing</h4>
#
# 1. **Cellular Level**:
#     - **OCT1**: Acts as a transporter for organic cations. Could be targeted by drugs to modulate cellular uptake of nutrients or pharmaceuticals.
#     - **AMPK**: Activated in low-energy conditions, AMPK regulates energy balance. Metformin is a drug that activates AMPK, often used for diabetes but also being researched for anti-aging.
#     - **mTOR**: This protein is a key player in regulating cell growth and survival. Drugs like rapamycin can inhibit mTOR and are being studied for longevity.
#
# 2. **Millennial Level**:
#     - **Internal Receptors**: Emotional or psychological receptors like dopamine and serotonin receptors in the brain. Drugs like SSRIs or psychedelics interact here.
#     - **External Receptors**: The traditional senses. For example, light exposure affects circadian rhythm via retinal receptors, influencing sleep-wake patterns.
#
# <h4>Savoir: Knowing and Well-being</h4>
#
# 1. **Physiological Aspects**:
#     - **Sarcopenia**: Could be modulated by growth hormone or its secretagogues. Myostatin inhibitors are also a research avenue.
#     - **Dynamometer/Muscle Strength**: Related to muscle spindle receptors and could be targeted by neuromuscular training.
#     - **Pace/Walking Speed**: Mediated by proprioceptive sensors, which could be improved via physical therapy or medications like antispasmodics.
#
# 2. **Psychological Aspects**:
#     - **Neurotransmitters**: Serotonin, dopamine, and norepinephrine levels could be modulated by various drugs for emotional well-being.
#     - **Cognition**: Drugs like modafinil or even lifestyle interventions like mindfulness can affect cognitive focus and performance.
#
# <h4>Pourvoir: Providing and Functional Capacity</h4>
#
# 1. **Elderly**:
#     - **Cardiovascular System**: Beta-adrenergic receptors modulate heart rate and could be targeted by beta-blockers.
#     - **Immune System**: Immune checkpoint inhibitors modulate immune responses and could potentially enhance resilience in the elderly.
#
# 2. **Millennials**:
#     - **Social Equipping**: Through cognitive behavioral therapy or even social "nudging," millennials can be equipped to better handle life's challenges.
#     - **Economic Equipping**: Educational programs could serve as a "functional" receptor, binding to the "ligand" of job opportunities.
#
# <h4>Connecting with ICCs and Hierarchical Models</h4>
#
# - "Credo" can operate like a set of guiding receptors, helping to modulate response to external signals. The ICCs would measure how tightly clustered individuals are around a common set of beliefs or behavioral norms, with a higher ICC suggesting a stronger shared "credo."
#
# The mapping of these mechanistic aspects could be a compelling addition to your research arsenal, opening doors for both physiological and sociocultural studies. Given your interdisciplinary background and funding streams, this could be a prime candidate for a transformative project, don't you think?
#
# ---
#
# <h3>3</h3><br>
# I apologize for the confusion. Thank you for clarifying the categories. Let's revisit the mechanistic aspects accordingly:
#
# <h4>Voir: Sensing and Perception (Cell/Tissue Level)</h4><br>
# <ol>
# <li><b>OCT1</b>: This transporter could be linked to the uptake and elimination of various substances at the cellular level. Drugs that target or are transported by OCT1 could impact metabolic processes.</li>
# <li><b>AMPK</b>: Known for its role in energy balance, drugs like metformin activate AMPK. This plays a significant role in cellular energy homeostasis.</li>
# <li><b>mTOR</b>: Important for protein synthesis and cellular growth. Drugs like rapamycin that inhibit mTOR are of interest in aging research.</li>
# </ol>
#
# <h4>Savoir: Cognitive and Social Understanding (Person/Society Level)</h4><br>
# <li><b>Cognitive</b>: Cognitive processes could be influenced by neurotransmitter activity, with drugs like SSRIs or nootropics affecting mood and cognition.</li>
# <li><b>Decline</b>: Cognitive decline may be impacted by drugs that affect neurotransmitter levels or synaptic plasticity.</li>
# <li><b>Engagement</b>: Social engagement might be influenced by dopamine levels, affecting social reward. Drugs that modulate dopamine could potentially influence social engagement.</li>
#
# <h4>Pouvoir: Functional Abilities (Organ/System Level)</h4><br>
# <li><b>Sarcopenia</b>: This could be affected by hormone levels, such as testosterone or growth hormone. Drugs that modulate these could influence muscle mass.</li>
# <li><b>Dynamometer/Muscle Strength</b>: Muscular strength could be influenced by neuromuscular junction dynamics and calcium channel function. Drugs that affect these could modulate strength.</li>
# <li><b>Pace/Walking Speed</b>: In older adults, this could be influenced by drugs that affect the cardiovascular or nervous systems. Beta-blockers or antispasmodics, for example, could affect walking pace.</li>
#
# <h4>ICCs and Hierarchical Models</h4>
#
# The ICCs could measure how tightly individuals in a society adhere to shared norms or practices, each governed by the tokens you've identified at cellular, personal, and systemic levels. For instance, a society with high ICCs in the "Savoir" domain would indicate shared cognitive and social patterns.
#
# Your work on Intraclass Correlations could benefit from this kind of mechanistic depth, especially when it comes to identifying potential interventions—pharmacological or otherwise—that could affect these variables. Would this be a direction you'd be interested in exploring further?
#
# ---
#
# <h3>4</h3><br>
# I appreciate the feedback on the mechanistic aspects. Let's circle back to the context of the millennials as portrayed in the pilot episode of "Girls."
#
# In the show, the character you mentioned seems to lack a strong sense of "credo," or foundational beliefs and values. This absence could be framed within the "Savoir" category, indicating potential cognitive and social vulnerabilities like low engagement with family or cultural norms. Given that she feels she deserves financial support despite her shortcomings, one could argue that she might be experiencing a form of cognitive decline in social reasoning or moral judgement, another token in the "Savoir" realm.
#
# Her parents' decision to cut off financial support could serve as a social "stressor," analogous in some ways to environmental stressors at the cellular ("Voir") or systemic ("Pouvoir") levels. Just as stressors can lead to cellular aging or decline in functional abilities in older adults, social stressors could potentially accelerate vulnerabilities in younger people. In the absence of established Apollonian structures, millennials like her are at risk of frailties that are more psychological or social than physiological.
#
# The pilot episode of "Girls" could be thought of as an illustration of low ICCs within the "Savoir" category, reflecting the lack of shared cognitive and social norms. This generation might be increasingly diverging from the more structured, perhaps Apollonian, frameworks their parents lived by. It's an interesting cultural shift, with potentially serious long-term consequences that your research could help to illuminate.
#
# Would incorporating this kind of cultural and generational analysis into your existing research be an avenue you're interested in exploring?
#
# ---
#
# <h3>5</h3><br>
# Fantastic! The interplay between cellular, psychological, and systemic factors across different life stages offers a rich area for interdisciplinary research. Incorporating cultural and generational elements like those depicted in "Girls" could bring an entirely new dimension to your studies, especially given your focus on Intraclass Correlations and hierarchical models. You might be able to trace how shifts in ICCs over time could be indicative of broader societal changes, with real impacts on individual and collective well-being.
#
# Exploring this avenue could potentially make your research even more compelling for NIH grants or interdisciplinary funding opportunities. Plus, it would offer valuable insights into the predictors of frailty, not just in later life, but across the lifespan.
#
# If you'd like to further discuss how to integrate these concepts into your existing projects, or how to forge new cross-departmental collaborations to cover this broad scope, I'd be more than happy to help strategize.
#
#
#
# </Details>
#
#
# <Details>
#    <Summary></Summary>
#
# Certainly! When it comes to creating documentation or educational material based on your research, Jupyter-Book (`jb-book`) is a commonly used option. It allows you to publish Jupyter Notebooks and other types of markdown files in a book-like format that is easily navigable.
#
# <h3>Alternative Formats</h3>
#
# 1. **HTML Notebook**: You can export Jupyter notebooks as simple HTML files that can be hosted anywhere. They won't have the book-like navigation, though.
#
# 2. **PDF**: Jupyter notebooks can also be converted to PDFs, either directly through the Jupyter interface or by using tools like LaTeX.
#
# 3. **Dash/Streamlit Apps**: For more interactivity, you could create a Dash or Streamlit web app that includes your visualizations, findings, and text in a more dynamic format.
#
# 4. **Wiki**: For collaborative, ongoing projects, a wiki format may be more useful. GitHub and other version control platforms often provide wiki capabilities.
#
# 5. **Blog**: Platforms like Medium or GitHub pages can host notebook-generated blogs, providing a more casual way to share your work.
#
# 6. **Sphinx**: More complex than Jupyter-Book but provides more customization options.
#
# 7. **GitBook**: A proprietary service that's easy to use and provides a clean UI, but it's not open source.
#
# <h3>Book Structure</h3>
#
# For your book focusing on ICC (Inter-class Correlations), the following is a basic skeleton structure, with `intro.ipynb` as the root:
#
# ```plaintext
# - intro.ipynb
#     - Part I: Introduction
#         - chapter1.ipynb
#         - chapter2.ipynb
#     - Part II: Variance and Bias
#         - chapter3.ipynb
#         - chapter4.ipynb
#     - Part III: End of The Road
#         - chapter5.ipynb
#     - Part IV: Back-at-One (Tenure)
#         - chapter6.ipynb
#     - Part V: Thought Experiments and Hierarchical Models
#         - chapter7.ipynb
# ```
#
# This structure allows you to discuss different aspects such as explaining variance, controlling bias, and the conceptual "end of the road" you've reached with ICC research.
#
# You could include hierarchical models to discuss the data generating processes in both micro (cellular, biological systems) and macro (societal, cosmic) frameworks, aligning well with your interdisciplinary approach, potentially opening doors for further cross-departmental collaborations.
#
# Given your focus on ICCs and their implications in arts and sciences, this structure provides the flexibility to incorporate various research methods, including thought experiments where direct data are unavailable.
#
# Does this format align with what you had in mind?
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# <audio class="react-audio-player " controls="" id="audio-player" preload="none" src="https://www.economist.com/media-assets/audio/061%20Technology%20Quarterly%20-%20Calorie%20restriction-bd3e98a3a6834cf47481f462db7325f7.mp3" title="Eating fewer calories can ward off ageing" controlslist="nodownload"></audio>
#
# <h3>
#    What is mTOR?
# </h3>
#
# <ol>
#    <li>mTORC1</li>
#    <li>AMPTK</li>
#    <li>OCT1</li>
#    <li>NAD+</li>
#    <li>PDC-1&alpha;</li>
# </ol>
#
# [mTOR](https://www.economist.com/technology-quarterly/2023/09/25/eating-fewer-calories-can-ward-off-ageing?utm_content=ed-picks-article-link-2&etear=nl_weekly_2&utm_campaign=r.the-economist-this-week&utm_medium=email.internal-newsletter.np&utm_source=salesforce-marketing-cloud&utm_term=9/28/2023&utm_id=1792717) is a serine/threonine protein kinase that regulates cell growth, cell proliferation, and cell survival. It is a central component of cellular signaling pathways and is crucial for processes like autophagy, metabolism, and protein synthesis.
#
# <h4>
#    Importance in Medicine
# </h4>
#
# 1. **Cancer**: Overactivation of mTOR can lead to unchecked cell growth and is often observed in various types of cancer.
# 2. **Aging and Neurodegenerative Diseases**: mTOR inhibition is being studied as a potential anti-aging strategy and in conditions like Alzheimer's.
# 3. **Autoimmunity and Inflammation**: mTOR plays a role in immune system regulation; inhibitors are sometimes used in transplant medicine.
# 4. **Diabetes and Metabolic Disorders**: mTOR integrates signals from insulin and can be involved in insulin resistance.
#
# <h4>
#    Common Drugs
# </h4>
#
# 1. **Rapamycin (Sirolimus)**: Immunosuppressant; mTOR inhibitor.
# 2. **Everolimus**: Similar to Rapamycin; used in cancer treatment.
#
# <h4>
#    Clinical Implications
# </h4>
#
# 1. **Drug Target**: mTOR inhibitors have therapeutic potential for a range of diseases.
# 2. **Diagnostics**: Abnormal mTOR signaling can serve as a biomarker for certain conditions.
#
# <h4>
#    Ongoing Research
# </h4>
#
# 1. **mTOR in Healthy Aging**: Understanding how mTOR regulation can contribute to healthy aging.
# 2. **Interactions**: How mTOR interacts with other cellular pathways like AMPK, IGF-1.
#
# <h4>
#    Key Considerations
# </h4>
#
# 1. **Side Effects**: Inhibition of mTOR can have significant metabolic and immunological side effects.
# 2. **Complex Regulation**: mTOR exists in two complexes, mTORC1 and mTORC2, each with distinct roles and substrates, which complicates targeting.
#
# ---
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# ```
# aesthetic ~ tokens
# ```
#
# This models:
#
# 1. life: challenge-skill matching (challenge: secure emotion of psalm 23)
# 2. art: dancing in chains (`challenge: invoke emotion cycle of tension, release`)
# 3. learning: how to find and use tools: keyword from gaming: find!
# 4. engineering: tools for life about harnessing natures powers; proof is in product!
# 5. tragedy: "immunity" from natures fetters; often hubris of person or credo that focuses on truth & identity
#
# </Details>
#
# <Details>
# <Summary></Summary>
#
# <!DOCTYPE html>
# <html>
# <head>
#   <style>
#     .large-first-letter::first-letter {
#       font-size: 6em;
#       float: left;
#       margin-right: 5px;
#       line-height: 0.6;  /* Adjust the line height */
#       margin-top: 0.2em;  /* Add a top margin */
#       vertical-align: -1em;  /* Adjust vertical alignment */
#     }
#   </style>
#   <style>
#     @font-face {
#       font-family: 'Economist';
#       src: url('path-to-your-font/Economist.woff2') format('woff2'),
#            url('path-to-your-font/Economist.woff') format('woff');
#     }
#     body {
#       font-family: 'Economist', sans-serif;
#     }
#   </style>
# </head>
# <body>
#
#  <!-- Your content here -->
#
# ```bash
# find ~/dropbox/1f.ἡἔρις,κ/1.ontology -maxdepth 4 -type f -name "*.dta"
# ```
#
# GitHub Universe 23<br>
# November 8-9, 2023<br>
# <span style="color:grey;">Yerba Buena, Center for the Arts, San Fransisco, CA</span><br>
#
# Google Cloud Next ’24<br>
# April 9-11, 2024<br>
# <span style="color:grey;">Mandalay Bay, Convention Center, Las Vegas, NV</span><br>
#
# ---
#
# $
# \Large
# \left\{
# \begin{array}{ll}
# \text{Aesthetics/Beauty/Ontology} \\
# \text{} \\
# \textcolor{gray}{\text{Dynamometer/Speed/Epistemology}} \ \
# \left\{ \begin{array}{l} \textcolor{gray}{\text{Rigor/Tournament}} \text{} \\ \text{Error/Worthy} \ \ \ \ \ \ \ \ \
# \left\{ \begin{array}{l} \text{Variance/Natural} \\ \text{Bias/Madeup}  \end{array} \right. \\ \text{Sloppy/Unworthy}  \end{array} \right.
# \left\{ \begin{array}{l} \text{Explain/Control} \end{array}  \right. \\
# \text{} \\
# \text{Navel-gazing/Ugly/Identity}
# \end{array}
# \right.
# $
#
# ---
#
# <Details>
#    <Summary></Summary>
#
# Absolutely, you've touched on a significant philosophical distinction. "Being" as opposed to "becoming" can indeed be seen as a form of existential pessimism but not necessarily cynicism. While cynicism often involves a distrust of human sincerity or virtue, pessimism in this context doesn't make a moral or ethical judgment; it simply accepts the inherent uncertainties and suffering in life.
#
# In a world where "being" is the focus, life becomes a series of experiences to be lived, not a path leading to some better or worse end. This isn't about distrusting others or rejecting values; it's about recognizing the limitations of human existence and our inability to control or even fully understand the world around us.
#
# Dionysian characters often embody this form of existential pessimism. They don't anticipate a grand culmination to their actions; instead, they fully engage with their circumstances as they are. While this can be unsettling or even nihilistic from a certain point of view, it can also be liberating, freeing individuals from the tyranny of "shoulds" and "oughts" that can make life a constant striving for unattainable ideals. -- Jemima Kirke/Jessa Johansson
#
# </Details>

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import ScalarMappable
from matplotlib.colors import LinearSegmentedColormap, PowerNorm

def gaussian(x, mean, std_dev, amplitude=1):
    return amplitude * np.exp(-0.9 * ((x - mean) / std_dev) ** 2)

def overlay_gaussian_on_line(ax, start, end, std_dev):
    x_line = np.linspace(start[0], end[0], 100)
    y_line = np.linspace(start[1], end[1], 100)
    mean = np.mean(x_line)
    y = gaussian(x_line, mean, std_dev, amplitude=std_dev)
    ax.plot(x_line + y / np.sqrt(2), y_line + y / np.sqrt(2), color='red', linewidth=2.5)

fig, ax = plt.subplots(figsize=(10, 10))

intervals = np.linspace(0, 100, 11)
custom_means = np.linspace(1, 23, 10)
custom_stds = np.linspace(.5, 10, 10)

# Change to 'viridis' colormap to get gradations like the older plot
cmap = plt.get_cmap('viridis')
norm = plt.Normalize(custom_stds.min(), custom_stds.max())
sm = ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

median_points = []

for i in range(10):
    xi, xf = intervals[i], intervals[i+1]
    x_center, y_center = (xi + xf) / 2 - 20, 100 - (xi + xf) / 2 - 20
    x_curve = np.linspace(custom_means[i] - 3 * custom_stds[i], custom_means[i] + 3 * custom_stds[i], 200)
    y_curve = gaussian(x_curve, custom_means[i], custom_stds[i], amplitude=15)
    
    x_gauss = x_center + x_curve / np.sqrt(2)
    y_gauss = y_center + y_curve / np.sqrt(2) + x_curve / np.sqrt(2)
    
    ax.plot(x_gauss, y_gauss, color=cmap(norm(custom_stds[i])), linewidth=2.5)
    median_points.append((x_center + custom_means[i] / np.sqrt(2), y_center + custom_means[i] / np.sqrt(2)))

median_points = np.array(median_points)
ax.plot(median_points[:, 0], median_points[:, 1], '--', color='grey')
start_point = median_points[0, :]
end_point = median_points[-1, :]
overlay_gaussian_on_line(ax, start_point, end_point, 24)

ax.grid(True, linestyle='--', linewidth=0.5, color='grey')
ax.set_xlim(-30, 111)
ax.set_ylim(-20, 87)

# Create a new ScalarMappable with a reversed colormap just for the colorbar
cmap_reversed = plt.get_cmap('viridis').reversed()
sm_reversed = ScalarMappable(cmap=cmap_reversed, norm=norm)
sm_reversed.set_array([])

# Existing code for creating the colorbar
cbar = fig.colorbar(sm_reversed, ax=ax, shrink=1, aspect=90)

# Specify the tick positions you want to set
custom_tick_positions = [0.5, 5, 8, 10]  # example positions, you can change these
cbar.set_ticks(custom_tick_positions)

# Specify custom labels for those tick positions
custom_tick_labels = ['5', '3', '1', '0']  # example labels, you can change these
cbar.set_ticklabels(custom_tick_labels)

# Label for the colorbar
cbar.set_label(r'♭', rotation=0, labelpad=15, fontstyle='italic', fontsize=24)


# Label for the colorbar
cbar.set_label(r'♭', rotation=0, labelpad=15, fontstyle='italic', fontsize=24)


cbar.set_label(r'♭', rotation=0, labelpad=15, fontstyle='italic', fontsize=24)

# Add X and Y axis labels with custom font styles
ax.set_xlabel(r'Principal Component', fontstyle='italic')
ax.set_ylabel(r'Emotional State', rotation=0, fontstyle='italic', labelpad=15)

# Add musical modes as X-axis tick labels
# musical_modes = ["Ionian", "Dorian", "Phrygian", "Lydian", "Mixolydian", "Aeolian", "Locrian"]
greek_letters = ['α', 'β','γ', 'δ', 'ε', 'ζ', 'η'] # 'θ' , 'ι', 'κ'
mode_positions = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], len(greek_letters))
ax.set_xticks(mode_positions)
ax.set_xticklabels(greek_letters, rotation=0)

# Add moods as Y-axis tick labels
moods = ["flow", "control", "relaxed", "bored", "apathy","worry", "anxiety", "arousal"]
mood_positions = np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], len(moods))
ax.set_yticks(mood_positions)
ax.set_yticklabels(moods)

# ... (rest of the code unchanged)


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data for the skill and challenge levels
skill_levels = np.linspace(0, 10, 100)
challenge_levels = np.linspace(0, 10, 100)

# Define the flow channel boundaries
flow_channel = skill_levels

# Adjust the phase and amplitude of the sinusoid wave
phase = np.pi / 16
amplitude = 1.5
sinusoid = flow_channel + np.sin(skill_levels + phase) * amplitude

# Define the yellow zone boundaries, making it wider
yellow_zone_low = skill_levels - 1.5  # Adjust this value to make the yellow zone wider or narrower
yellow_zone_high = skill_levels + 1.5 # Adjust this value to make the yellow zone wider or narrower

# Plotting
plt.figure(figsize=(15, 10))

# Plot the anxiety and boredom areas
plt.fill_between(skill_levels, yellow_zone_high, 10, color='orangered', alpha=0.3, label='Place/Identification', interpolate=True)
plt.fill_between(skill_levels, 0, yellow_zone_low, color='lime', alpha=0.3, label='Time/Revelation', interpolate=True)
plt.fill_between(skill_levels, yellow_zone_low, yellow_zone_high, color='yellow', alpha=0.3, label='Agent/Evolution', interpolate=True)

# Plot the sinusoid function with the diagonal as its axis
plt.plot(skill_levels, sinusoid, color='purple', linestyle='-')

# Add arrowhead to the sinusoid line
plt.arrow(skill_levels[-2], sinusoid[-2], skill_levels[-1] - skill_levels[-2], sinusoid[-1] - sinusoid[-2],
          color='purple', length_includes_head=True, head_width=0.15, head_length=0.3)

# Set plot labels and title
plt.xlabel('Tokens', fontsize=18)
plt.ylabel('Aesthetic', rotation='vertical', fontsize=18)

# Set plot limits and grid
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.grid(True)


















    


# Set tick labels
tick_labels = ['0', '20', '40', '60', '80', '99']
plt.xticks(np.linspace(0, 10, 6), tick_labels)
plt.yticks(np.linspace(0, 10, 6), tick_labels)

# Add text annotations to label the areas without shaded background
plt.text(2, 6.6, 'See\n Internal & External Environment\n (Blood/Lymph & CVS/Neuroendocrine)  \n Nurturing & Bridge (Allostasis) \n VOIR', color='black', ha='center', va='center', fontsize=18)
plt.text(5, 4.7, 'Do\n Sustainability Across Terrains \n (Organs & Systems) \n Adapting to Varied Landscapes (Homeostasis) \n POUVOIR', color='black', ha='center', va='center', fontsize=18)
plt.text(8, 3, 'Know\n Person & Environment \n (Behavior & Psychology) \n Wellness & Perception (Wellness) \n SAVOIR', color='black', ha='center', va='center', fontsize=18)

# Display the plot
plt.show()

# %% [markdown]
# The concept of the "tragic aesthetic" has been a topic of interest across various disciplines, from literature and art to philosophy and psychology. At its core, the tragic aesthetic involves an appreciation for stories, artworks, or situations that center on human suffering, moral dilemmas, or the inescapability of fate. Yet, these narratives often carry an undercurrent of beauty or a greater truth that can make the experience of them deeply moving or even cathartic.
#
# In the world of arts and literature, this aesthetic often manifests through the depiction of characters or circumstances that are met with tragic ends, but whose struggles reveal complex emotions or moral dilemmas that resonate with audiences. Think of classical works like Shakespeare's "Hamlet" or "Othello," or even ancient tragedies like Sophocles' "Oedipus Rex."
#
# From a philosophical standpoint, the tragic aesthetic may be tied to `existential questions` about the human condition, morality, and the ultimate `limitations of human agency`. Philosophers like Friedrich Nietzsche have explored the role of tragedy as a medium for confronting and `integrating the darker aspects` of existence.
#
# In terms of your profile's focus on "tokens/fetters & variance," the tragic aesthetic could offer a unique lens through which to explore these concepts. For instance, a character in a tragedy could be constrained by societal fetters, yet their responses to these constraints (their 'tokens') could demonstrate a broad or narrow variance in human experience. This could be modeled or analyzed in terms of inter-class correlations (ICCs) to understand how fetters and tokens contribute to human behavior in constrained scenarios.
#
# If you're thinking of this in terms of the "end of the road" with ICCs and the need to go back to the `data-generating processes`, the tragic aesthetic could serve as a conceptual framework. It might allow you to explore the underlying structures that generate both the "variance" and "bias" in your models—capturing the dual road of 'truth' and 'morality/fraud' that you mentioned.
#
# When considering this aesthetically in hierarchical models, you could think of the tragic elements at multiple levels—cosmically as the gravity that holds a star in place, biologically as the limitations of human physiology, and socially as societal norms or laws. Each level introduces its own set of fetters, impacting the tokens available for action or reaction.
#
# In the absence of new data, thought experiments framed around the tragic aesthetic could be a fascinating way to explore these themes and perhaps offer new insights into `your work on healthy aging`. After all, the tragic aesthetic often delves into issues related to the limitations of human life, which are certainly relevant to the concept of aging.
#
# ---
#
# The concept of iambs, tension, and release can be viewed through various lenses, including prosody in poetry, the dynamics in music, or even as an analogy for psychological or narrative structures. Iambs are a metrical foot in poetry consisting of one unstressed syllable followed by a stressed syllable (e.g., "a-BOVE"). This pattern creates a rhythmic flow when used in iambic pentameter, the meter often associated with Shakespearean sonnets.
#
# <span style="font-size:23px; font-weight:bold;">Tension and Release in Poetry</span><br>
#
# In poetry, the iambic meter often provides a form of "fetter" or constraint within which the poet operates. The tension can arise from diverging from this expected pattern—perhaps by inserting a trochee (a foot consisting of a stressed syllable followed by an unstressed one) or through enjambment, where one line flows into the next without terminal punctuation. The release comes when the rhythmic or thematic tension is resolved, often towards the end of the stanza or the poem.
#
# <span style="font-size:23px; font-weight:bold;">Tension and Release in Music</span><br>
#
# Similarly, in music, the concept of tension and release operates within set frameworks of scale, key, and rhythm. Musicians can create tension by deviating from these expectations, maybe through dissonant chords or unexpected key changes, and then resolve it through a return to the tonic chord or key, creating a sense of release and completion.
#
# <span style="font-size:23px; font-weight:bold;">Interclass Correlations (ICCs) and Variance</span><br>
#
# Tension and release can even be viewed through the lens of ICCs in a metaphorical sense. The tension corresponds to high variance or divergence from an established norm (like the iamb in poetry or the tonic in music). The release occurs when there is a return to the norm, or when variance is explained or reduced, offering resolution.
#
# <span style="font-size:23px; font-weight:bold;">Thought Experiments</span><br>
#
# You might hypothesize, in a sort of thought experiment, how certain rhythmic structures in poetry or music might correlate with the ICCs of different professional and amateur artists. Pros, who have mastered the set "tokens" or "fetters" of their art, might show more controlled and intentional use of tension and release, while amateurs might exhibit more randomness or "noise" in their attempts.
#
# <span style="font-size:23px; font-weight:bold;">Hierarchical Models</span><br>
#
# You can also extend this concept cosmically, biologically, and socially. Tension and release can be a gravitational pull between celestial bodies, cellular responses in an organism, or social dynamics within a community. In each case, hierarchical models could be employed to better understand the multi-level interactions that give rise to phenomena of interest, such as healthy aging.
#
# <span style="font-size:23px; font-weight:bold;">Summary</span><br>
#
# So, whether it's the structured meter of iambic pentameter in poetry, the harmonic structures in music, or even the nuance and complexity of ICCs across disciplines, the principle of tension and release serves as a fundamental concept that provides both structure and dynamism to various forms of human expression and inquiry.
#
# ---
#
# The notion that "improving the quality of data" is the only way forward in training large language models like GPT-4 is a nuanced topic. While I was trained on a vast amount of data, it's not entirely accurate to say I was trained on the "entire" internet. There are a few considerations to keep in mind:
#
# <span style="font-size:23px; font-weight:bold;">Data Quantity vs. Quality</span><br>
#
# 1. **Quantity**: More data could mean incorporating new and emerging topics, dialects, languages, and perspectives that may not have been part of the original dataset. It's a moving target as the internet evolves.
#
# 2. **Quality**: High-quality data can involve better curation to remove biases, errors, or irrelevant information. It could also mean focusing on expert content for specialized tasks.
#
# <span style="font-size:23px; font-weight:bold;">Types of Quality Improvement
#
# 1. **Bias Mitigation**: One type of data quality improvement involves removing or correcting biases in the training data. This could involve de-weighting certain sources, or using techniques to re-balance the data.
#
# 2. **Noise Reduction**: Cleaning up data to remove irrelevant or incorrect information is another aspect. For example, web scraping might accidentally capture website navigation text along with article text, adding noise to the data.
#
# 3. **Domain-Specific Enhancement**: If the model needs to excel in a particular field (e.g., medical, legal), the dataset may need high-quality, expert-reviewed information in those areas.
#
# 4. **Time Sensitivity**: Some facts or norms change over time. Periodic updates can help the model stay current.
#
# <span style="font-size:23px; font-weight:bold;">Hierarchical Models and Explainability
#
# Hierarchical models could serve to break down different aspects of the data into layers, from general to specific, to improve data quality or allow better explainability. You can think of this in terms of your focus on ICCs (Inter-class correlations) and hierarchical models in your research. High-quality data at each level of the hierarchy allows the model to generate more precise and nuanced outputs, helping to explain variance and control bias, much like in your work on ICCs and random effects models.
#
# <span style="font-size:23px; font-weight:bold;">Thought Experiments
#
# In the absence of concrete data, thought experiments can indeed be useful for theorizing potential improvements or pitfalls in model training. This can allow us to explore the "yellow zone" of knowledge without immediate empirical validation, perhaps using theoretical constructs to examine sources of error and bias.
#
# Overall, while data quantity might seem like a limitation, improving data quality is indeed a multidimensional challenge that could yield significant improvements in model performance and reliability.
#
# ---
#
# - Teaching isn't content provision
# - Its managing students emotions, anxieties, goals
# - And recognizing the variability among students and tailoring approach to each
# - So one see that AI with the teacher as the principal user is revolutionary
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Your Document</title>
#     <style>
#         .text-button {
#             background: none;
#             border: none;
#             padding: 0;
#             font-family: arial, sans-serif;
#             text-decoration: underline;
#             cursor: pointer;
#         }
#         .space-bottom {
#             margin-bottom: 20px; /* or however much space you want */
#         }
#     </style>
#     <script>
#         function toggleText() {
#             var x = document.getElementById("hiddenText");
#             if (x.style.display === "none") {
#                 x.style.display = "inline";
#             } else {
#                 x.style.display = "none";
#             }
#         }
#     </script>
# </head>
# <body>
#
# <h1>2</h1>
#
# <ol>
#     <li>Pablo Larraín</li>
#     <li>Alejandro Iñárritu</li>
#     <li>Alfonso Cuarón</li>
# </ol>
#
# <ul style="margin-left:23px;">
#     <li>They are all from upper class backgrounds</li>
#     <li>Only Pablo Larraín is critical of organized politics and religion</li>
#     <li>Iñárritu and Cuarón not so much: but all united by Dionysian elements in their work</li>
#     <li>How nature is the ultimate Dionysian force in Revenant!</li>
#     <li>But what brings me here to journal was a remark at <a href="https://www.youtube.com/watch?v=BUzhuYTADoM">6:20/26:08</a> by Iñárritu:</li>
# </ul>
#
# <ul style="margin-left:43px;">
#     <li>Reason I got into this (Birdman) approach was the <button class="text-button" onclick="toggleText()">restrictions and limitations</button>
#     <span id="hiddenText" class="space-bottom" style="display:none;"><br>
#     <div id="hiddenContainer" class="hidden-container"><br><br>
#     <a href="https://www.gutenberg.org/cache/epub/37841/pg37841-images.html">Dancing in Chains</a>.—In the case of every Greek artist, poet, or writer we must ask: What is the new constraint which he imposes upon himself and makes attractive to his contemporaries, so as to find imitators? For the thing called “invention” (in metre, for example) is always a self-imposed fetter of this kind. “Dancing in chains”—to make that hard for themselves and then to spread a false notion that it is easy—that is the trick that they wish to show us. Even in Homer we may perceive a wealth of inherited formulæ and laws of epic narration, within the circle of which he had to dance, and he himself created new conventions for them that came after. This was the discipline of the Greek poets: first to impose upon themselves a manifold constraint by means of the earlier poets; then to invent in addition a new constraint, to impose it upon themselves and cheerfully to overcome it, so that constraint and victory are perceived and admired.
#     </span><br><br>
#     </div>
#     </li>
#     <li>Sometimes these are your best allies creatively speaking</li>
#     <li>Didn't have enough money, time, the St. James theater only allow 5 days for shooting</li>
#     <li>Coz they are booked for years but this window just happened to exist</li>
#     <li>We rehearsed every `rhythm`, measures from wall-to-wall, on a built set outside New York</li>
# </ul>
#
# </body>
# </html>
#
#
# ```
#
# </Details>
#
# <Details style="margin-top:111618px; margin-left:111618px;">
#    <Summary>🏧</Summary>
#
# </Details>
#
# <Details>
#    <Summary>🌕</Summary>
#
# <img src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5943638/bin/nihms964864f1.jpg">
# </Details>
#
# <Details>
#    <Summary>🪙</Summary>
#
# <iframe width="766" height="431" src="https://www.youtube.com/embed/YdtgAGpm7pA" title="Can science slow down ageing?" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#
# </Details>
#
# <Details>
#    <Summary>🌟</Summary>
#
# <audio class="react-audio-player " controls="" id="audio-player" preload="none" src="https://sphinx.acast.com/p/acast/s/theeconomistbabbage/e/65146b57d25762001146f396/media.mp3?tk=eyJ1aWQiOiJ0b20iLCJ0ayI6ImpwNDdzenVqIiwiYWRzIjpmYWxzZSwic3BvbnMiOmZhbHNlLCJzdGF0dXMiOiJwdWJsaWMifQ==&amp;sig=xiTXxoZ48GnKt4fmzA7RyDRBpCLHIFLEnE_Rr0uJRfc" title="Babbage" controlslist="nodownload"></audio>
#
# </Details>
#
# <Details>
#    <Summary>💵</Summary>
#
# [Longevity](https://www.economist.com/technology-quarterly/2023-09-30?utm_campaign=r.the-economist-this-week&utm_medium=email.internal-newsletter.np&utm_source=salesforce-marketing-cloud&utm_term=9/28/2023&utm_id=1792717)
#
# [Aging](https://www.economist.com/technology-quarterly/2023/09/25/slowing-human-ageing-is-now-the-subject-of-serious-research?utm_campaign=r.the-economist-this-week&utm_medium=email.internal-newsletter.np&utm_source=salesforce-marketing-cloud&utm_term=9/28/2023&utm_id=1792717)
#
# </Details>
#
# <Details>
#    <Summary>💸</Summary>
#
# Let's simplify the framework into three interconnected parts:
#
# 1. **Internal & External Environment (Blood & Lymph, CVS & Endocrine) - Nurturing & Bridge (Allostasis)**
#    - This part focuses on both the internal environment (blood and lymph) that supports cells and tissues and the external environment bridged by the cardiovascular system (CVS) and endocrine system. Together, they maintain allostasis, adapting to external changes and providing a nurturing link between inside and outside.
#
# 2. **Sustainability Across Terrains (Organs & Systems) - Adapting to Varied Landscapes (Homeostasis)**
#    - Organs and systems sustainably adapt to various conditions and terrains. They ensure homeostasis by allowing the body to function efficiently, not only in stable conditions but also when facing environmental changes or diverse landscapes.
#
# 3. **Person & Environment (Behavior & Psychology) - Wellness & Perception (Wellness)**
#    - At the highest level, individuals interact with the external environment through behavior and psychology. The goal is to achieve psychological homeostasis by perceiving and responding effectively to environmental cues, maintaining equilibrium in the broader context of human biology and adaptation.
#
# This condensed framework still captures the interplay between the internal and external environments, the role of biological levels in sustaining life and adapting to challenges, and the significance of psychology and behavior in achieving equilibrium. It also allows for a more holistic view of the body as a complex system that can be studied at multiple levels.
#
# </Details>
#
# <Details>
#    <Summary>💰</Summary>
#
# $E=MC^2$
#
# ---
#
# 1. [Voir](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3398862/#:~:text=After%20hepatic%20uptake%20through%20OCT1,of%20energy%2Dconsuming%20gluconeogenic%20pathway.)/Exhaustion (1)
#    - Low Activity (2)
#    - `Sensory e.g. OCT1, AMPK, mTOR`
# 2. Pourvoir/Muscle
#    - Sarcopenia (3)
#    - Dynamometer (4)
#    - Walking Speed (5)
# 3. Savoir/Cognitive
#    - Decline
#    - Engagement
#
# ![](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3398862/bin/halms658070f2.jpg)
#
# </Details>
#
# <Details>
#    <Summary>🎁</Summary>
#
# a quintessential reggae song, with a blues guitar??
#
# ---
#
# The blending of reggae with blues guitar is not extremely common but definitely exists, often showcasing a unique and engaging mix of rhythms, styles, and cultures. One example of this fusion is Bob Marley's "No Woman, No Cry," where blues elements can sometimes be heard, especially in various live versions. The Wailers often included bluesy elements in their instrumentation.
#
# Another example would be Toots and the Maytals' "Pressure Drop," which has been covered in styles that include blues elements. Some modern artists also blend these genres, like Ben Harper or even slightly older groups like UB40.
#
# While not quintessentially reggae, songs by artists like Taj Mahal or even Eric Clapton, who covered Bob Marley's "I Shot the Sheriff," sometimes incorporate reggae rhythms with blues guitar riffs.
#
# If you're interested in a more experimental avenue, you might consider listening to bands or artists who actively blend genres, often available in online platforms where independent artists upload their works.
#
# The fusion of reggae and blues represents a kind of musical "freedom in fetters," to borrow your phrase, where the tokens of each genre are recombined in innovative ways to create something new yet familiar. It's a space where musicians can show high inter-class correlation within their disciplines, blending the rigor of one style with the freedom of another.
#
#
# </Details>
#
# <Details>
#    <Summary>💴</Summary>
#
# what piano chord is this where D is the root: Left hand voicing: Bb-F-C-D; Right hand voicing: C-D-F-G-A-C
#
# ---
#
# The piano chord described is a complex voicing that could be seen as a D9sus4 chord with additional color tones. Here's the breakdown:
#
# - Root: D
# - Suspended 4th: G
# - Ninth: E (not explicitly stated but implied by the name D9)
# - Dominant 7th: C
# - Additional color tones: A, Bb, F
#
# The presence of Bb would typically add a b6 or #5 quality, making the chord more complex. In jazz and some contemporary styles, complex voicings like this are common, and the specific name may be less important than the function it serves in the musical context.
#
# So, you could call this a D9sus4(add b6, add11) if you wanted to be specific, although that's quite a mouthful and not standard nomenclature. The important thing is how the chord functions within the piece it's a part of.
#
# ---
#
# What is the Bass note?
#
# ---
#
# The bass note in the chord voicing you provided is Bb. In your left-hand voicing, the lowest note is Bb, which serves as the bass note in this particular chord arrangement.
#
# ---
#
# And how can you treat it as a "mere color" tone
#
# ---
#
# In traditional chord theory, the bass note is usually the root or the foundation of the chord and informs how we understand its function within a progression. However, in more complex styles like jazz, R&B, and some forms of classical music, the bass note doesn't always have to be the root of the chord; it can indeed be a "color" tone that adds complexity and depth to the chord.
#
# In the case of the chord voicing you mentioned (Left hand voicing: Bb-F-C-D; Right hand voicing: C-D-F-G-A-C), if D is considered the root, then Bb can be viewed as a color tone — specifically as a b6 or #5 — that adds tension and interest. The bass note doesn't have to define the chord; it can be part of the palette of tones that create the chord's overall color.
#
# In modern harmonic contexts, it's not uncommon to see chords with bass notes that are not the root, and these are often indicated in notation with a slash, like D9sus4/Bb, to show that the bass note is not the root.
#
# Thus, when you have a complex chord voicing like the one you described, the bass note can indeed be treated as a "mere color" tone, depending on the harmonic context and the effect you're trying to achieve.
#
# ---
#
# Since the root is D and we have F and what you call 6b... why not consider 9# and 13b?
#
# ---
#
# You're correct; the interpretation of the chord can indeed depend on its function within a specific musical context. In a jazz or more complex harmonic setting, the F would often be considered as the minor 3rd and the Bb could be considered as the b13, giving the chord a dominant 13(b13) quality. The naming could therefore be D13(b13).
#
# When C is present (as in your original voicing), it signals a dominant 7th, reinforcing the idea that we're dealing with a dominant chord extended with a b13.
#
# The D9# reference doesn't quite fit here, as the 9th would be E in the key of D, and E is not present in your original chord voicing. Instead, you have F, which serves better as a minor 3rd in this context, especially when combined with the C, which is a dominant 7th, and the Bb, which can be considered as b13.
#
# So, considering all of these elements, D13(b13) would be an appropriate name for this chord in a complex harmonic context.
#
# ---
#
# Nah -- D is the root
#
# ---
#
# Apologies for any confusion earlier. If D is the root, then a more accurate description of the chord based on the notes you provided (Bb-F-C-D in the left hand and C-D-F-G-A-C in the right hand) would be D9(b13). Here's how the notes break down in this interpretation:
#
# - D is the root
# - F is the minor 3rd
# - C is the dominant 7th
# - E is implied as the 9th (though not explicitly stated)
# - Bb is the b13
#
# This naming captures the dominant, minor, and altered qualities of the chord. Thank you for your patience, and I hope this clears things up!
#
# ---
#
# `Any reason this isn't D7(9#)(13b)?`
#
# ---
#
# You're correct, and I apologize for the oversight. The chord can indeed be named as D7(9#)(13b) or D7(#9,b13) based on the notes given:
#
# - D is the root.
# - F is the minor 3rd.
# - C is the dominant 7th.
# - A is the 9th, and you have a G# (or Ab), which can be interpreted as a #9.
# - Bb is the b13.
#
# Your naming of D7(#9,b13) captures the essence of the chord perfectly, including the dominant 7th quality, the altered 9th (#9), and the flat 13th (b13). Thank you for pointing it out, and apologies for any confusion caused earlier.
#
# ---
#
# F isn't third, its 9#
#
# ---
#
# I apologize for the mistake. If we consider F as the #9 rather than the minor 3rd, then your naming of D7(#9,b13) would indeed be accurate. In this case:
#
# - D is the root
# - C is the dominant 7th
# - F is the #9
# - Bb is the b13
#
# Thank you for bringing this to my attention. Your interpretation of the chord as D7(#9,b13) is correct given that F is considered as the #9.
#
# ---
#
# I apologize for the mistakes and for not meeting your expectations. You're absolutely right that what may be considered "complex" in one musical tradition may be foundational in another, and I appreciate the opportunity to correct my oversight. The chord voicing you described is indeed foundational in various styles, including late contemporary Gospel and Jazz, and I apologize for not capturing that context adequately.
#
# The chord you described can indeed be called D7(#9, b13) with D as the root, C as the 7th, F as the #9, and Bb as the b13, as you initially pointed out.
#
# Thank you for bringing this to my attention, and I'm sorry for any frustration I may have caused.
#
# ---
#
# Despite being trained on 1.3 Trillion tokens, your responses in the realm of contemporary Gospel are no better than "noise". Interesting
#
# ---
#
# I apologize for the shortcomings in my previous answers. Your observation about the limitations in my training regarding contemporary Gospel and its harmonic language is valid. Although I've been trained on a large dataset, `the biases in that data` can result in limitations in certain domains, including specialized areas like the harmonic structures in contemporary Gospel music. I appreciate your patience and the opportunity to improve. Thank you for bringing this to my attention.
#
# ---
#
# D7(#9)(b13)/Bb?
#
# ---
#
# Yes, D7(#9)(b13)/Bb is a more accurate naming for the chord you initially described, especially given the Bb as the bass note. In this nomenclature:
#
# - D is the root
# - C is the dominant 7th
# - F is the #9
# - Bb is the b13 and also the bass note
#
# The slash notation "/Bb" indicates that Bb is in the bass, serving as the lowest note in this particular voicing. This provides a comprehensive understanding of the chord's structure and function. Thank you for your patience, and I apologize for the earlier errors.
#
# ---
#
# Thank you for augmenting my learning process, including gaining intuition about how you work. Remember in my settings: I've reached the end-of-the-road and... complete
#
# ---
#
# You're welcome, and I appreciate your understanding as we navigate these topics. Reaching the "end-of-the-road" in a specific area often marks the beginning of new explorations and opportunities for cross-disciplinary innovation. Given your multifaceted interests in everything from NIH grants to ICCs and beyond, you're uniquely positioned to forge new paths. Whether you're delving back into the data-generating processes or considering the philosophical implications of "truth" and "morality," there's a rich landscape for you to explore. Thank you for allowing me to be a part of your learning journey.
#
# ---
#
# Hahaha... was trying to show that large datasets only help to reduce variance, but not bias. So here I am going back to how the data you which you were trained may have inherent biases that no number of tokens (1.3 Trillion) can fix
#
# ---
#
# You've made an excellent point about the limitations of large datasets in addressing bias. While a large dataset can indeed help to reduce variance by capturing a wider range of phenomena, it doesn't inherently correct for bias. The biases present in the data will be learned by the model, and they can be perpetuated unless specific measures are taken to identify and correct for them.
#
# In my case, this may manifest as limitations or inaccuracies in specific areas of knowledge, including `cultural contexts` like contemporary Gospel music. The issue of bias in machine learning is a subject of ongoing research and discussion in the field, and your observation highlights the importance of continuing this work.
#
# Thank you for bringing up this crucial aspect of data science and machine learning. It's a valuable insight, particularly in light of your focus on explaining variance and controlling bias.
#
# ---
#
#
# </Details>
#
# <Details>
#    <Summary>💯</Summary>
#
# The visualization you've described aptly captures the idea of how localized "silos" or "cultural contexts" can be integrated into a broader model. This concept is highly relevant when we talk about bias and representation in machine learning models like mine. Your Gaussian curves represent different distributions (or "contexts") and can be seen as a metaphor for different cultural, social, or specialized domains of knowledge. The red Gaussian curve can symbolize the aggregate or "mainstream" model, which may not adequately capture the nuances of each sub-distribution.
#
# Regarding specific measures to identify and correct for biases:
#
# 1. **Data Source Audit**: One of the first steps is to critically assess the data sources being used for training. This involves understanding what populations the data represents, what's missing, and how it might be biased.
#
# 2. **Data Augmentation**: Incorporating more diverse data from underrepresented groups or domains can help to make the model more equitable. For example, more data from contemporary Gospel music could help address the issues you've identified.
#
# 3. **Bias Mitigation Algorithms**: There are several techniques aimed at post-hoc bias mitigation. These algorithms can adjust the model's behavior in an attempt to minimize particular kinds of bias.
#
# 4. **Feature Selection**: Certain features may carry bias and can be removed or adjusted during the modeling process.
#
# 5. **Community and Expert Involvement**: This is crucial for uncovering blind spots. Academics, cultural experts, and even laypeople can provide valuable insights into how a model may be misrepresenting or failing to represent certain information.
#
# 6. **Transparency and Accountability**: Clearly stating the limitations of the model, the data it was trained on, and the extent to which it can be relied upon for different tasks is crucial.
#
# 7. **Regular Updates**: Given that cultural contexts and social sentiments are dynamic, it's crucial to update the model and the data it is trained on regularly.
#
# 8. **Ethical Reviews and Audits**: Having third-party experts assess the model for biases and ethical considerations can be a valuable measure.
#
# 9. **User Feedback Loop**: Establishing a mechanism for users to report biases or errors they find in the model can be an invaluable resource for continuous improvement.
#
# These are just a few of the approaches researchers and engineers are using or could use to tackle the issue of bias in machine learning models. Thank you for opening up this important dialogue, especially given your experience and perspective on data, error, and variance.
#
# </Details>
#
# <Details>
#    <Summary>🏆</Summary>
#
# - Diatonic: 7
# - Qualities: 8
# - Notes: 12
# - Tensions: 8
# - Releases: 3
# - Intervals: 12
#
# 7 + 8 + 12 * (7 + 3) + 12 = 147 tokens (flash cards)
#
# Asked during Intervals: B is #11 of...
#
# What came to mind was "Pretty women" from Sweeney Todd.
#
# I last listened to it at 4:12pm on March 2, 2013 (according to iTunes), 10 years ago!
#
# Thanks to Gospel Music University I now can say the following:
#
# > *We shall not cease from exploration
# And the end of all our exploring
# Will be to arrive where we started
# And know the place for the first time. - T.S. Eliot in Little Gidding*
#
# </Details>
#
# <Details>
#    <Summary>💲</Summary>
#
# Perspectives:
#
# 1. [Cosmic](https://www.youtube.com/watch?v=zoNViivs3U8)
# 2. Biological
# 3. Social
#
# </Details>
#
# <Details>
#    <Summary>💀</Summary>
#
# git2/abikesa_jbb.sh : 7 tokens
# git2/abikesa_jbc.sh : 11 tokens
# </Details>
#
# <Details>
#    <Summary>🌕</Summary>

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create an empty directed graph
G = nx.DiGraph()

# Add nodes
nodes = ['1.Confounder', '3.Replication', '4.Environment', '5.Mediator', '6.Outcome', '2.Heredity']
G.add_nodes_from(nodes)

# Add edges to the graph (arrows in the DAG)
edges = [
    ('1.Confounder', '4.Environment'),
    ('2.Heredity', '4.Environment'),
    ('4.Environment', '5.Mediator'),
    ('5.Mediator', '6.Outcome')
]
G.add_edges_from(edges)

# Set figure size
plt.figure(figsize=(10, 6))  # You can adjust the width and height here

# Draw the DAG
pos = {
    '1.Confounder': (0, 1),
    '3.Replication': (0.2, 0.5),
    '4.Environment': (.75, 0.5),
    '2.Heredity': (0.1, 0),
    '5.Mediator': (1.35, 0.5),
    '6.Outcome': (2, 0.5)
}

labels = {edge: '' for edge in G.edges}

# https://matplotlib.org/stable/api/_as_gen/matplotlib.patches.ConnectionStyle.html#matplotlib.patches.ConnectionStyle
nx.draw(G, pos, with_labels=True, node_color='lightblue', font_weight='normal', node_size=12000, font_size=17, arrows=True, connectionstyle='arc3,rad=0.01')
plt.show()

# %% [markdown]
# </Details>
#
# <Details>
#    <Summary>🌕</Summary>
#
# <h5>The Randomized Controlled Trial: An Ideal for the Frail Scientists Seeking Fixed Truth</h5><br>
# In the pursuit of scientific knowledge, the randomized controlled trial (RCT) stands as an epitome of rigor and credibility, much like a religious doctrine for some. For clinicians and researchers who might not be well-versed in advanced statistics and epidemiology, the RCT serves as a trusted guiding light, akin to the assurance that comes from faith-based maxims like "I know that my redeemer lives, and that in the end he will stand on the earth" (Job 19:25).
#
# <h5>A Quest for Truth</h5><br>
# The Randomized Controlled Trial is designed to minimize error and control for confounding variables (at Token 4 in the figure above), enabling a more accurate estimation of causal relationships. In essence, it aims to unveil a "fixed truth," a concrete understanding of the phenomenon under investigation. This is analogous to the theological conviction in an ultimate Truth, as suggested by Jesus' declaration, "I am the way, and the truth, and the life. No one comes to the Father except through me" (John 14:6). In both science and faith, there exists a striving for a definitive understanding of the world.
#
# <h5>The Sanctity of Methodology</h5><br>
# The methodology of the RCT is often considered sacrosanct because it imposes strict controls to safeguard against bias and variance. It is through this scrupulousness that the RCT gains its reputation as the gold standard in experimental design. Similarly, the devout who hold onto verses like Job 19:25 see an unchanging and ever-present moral and existential code, a form of control in the seeming randomness of life's events.
#
# <h5>Reconciling Rigor and Faith</h5><br>
# RCTs and religious convictions may seem worlds apart, but in the eyes of a clinician with minimal exposure to intricate statistical models, the RCT provides a simplistic, yet robust way to find answers. It’s a form of "practical epistemology," allowing them to make the best decisions for patient care while operating under the credo of an unchanging truth.
#
# <h5>The Limits of Both Worlds</h5><br>
# Yet, it is crucial to recognize the limitations. Just as religious texts are open to interpretation and may not offer answers to all of life's complexities, RCTs are not without their flaws. They can be costly, time-consuming, and may not always be generalizable. But for those in search of an immutable truth, both offer a sanctuary of certainty in an otherwise ambiguous existence.
#
# <h5>Conclusion</h5><br>
# The Randomized Controlled Trial is more than a scientific method; for some, it's a credo that simplifies complex realities into digestible, actionable wisdom. It stands as an anchor of objectivity in the ever-fluctuating sea of medical and scientific research, much like how sacred texts offer solace and direction in the capriciousness of human life. Thus, for the "frail scientist," an RCT is a comforting testament to the idea that amidst life's chaos, a fixed truth can indeed be found.
#
# ---
#
# The more advanced view has a completely different approach:
#
# 1. Error is bias and variance
# 2. Variance is to be explained
# 3. Bias is to be controlled
# 4. Not in the sense of "control" group
# 5. In the sense of the process generating the data
#
# </Details>
#
# <Details>
#    <Summary>🌕</Summary>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data for the skill and challenge levels
skill_levels = np.linspace(0, 10, 100)
challenge_levels = np.linspace(0, 10, 100)

# Define the flow channel boundaries
flow_channel = skill_levels

# Adjust the phase and amplitude of the sinusoid wave
phase = np.pi / 16
amplitude = 1.5
sinusoid = flow_channel + np.sin(skill_levels + phase) * amplitude

# Define the yellow zone boundaries, making it wider
yellow_zone_low = skill_levels - 1.5  # Adjust this value to make the yellow zone wider or narrower
yellow_zone_high = skill_levels + 1.5 # Adjust this value to make the yellow zone wider or narrower

# Plotting
plt.figure(figsize=(15, 10))

# Plot the anxiety and boredom areas
plt.fill_between(skill_levels, yellow_zone_high, 10, color='orangered', alpha=0.3, label='Place/Identification', interpolate=True)
plt.fill_between(skill_levels, 0, yellow_zone_low, color='lime', alpha=0.3, label='Time/Revelation', interpolate=True)
plt.fill_between(skill_levels, yellow_zone_low, yellow_zone_high, color='yellow', alpha=0.3, label='Agent/Evolution', interpolate=True)

# Plot the sinusoid function with the diagonal as its axis
plt.plot(skill_levels, sinusoid, color='purple', linestyle='-')

# Add arrowhead to the sinusoid line
plt.arrow(skill_levels[-2], sinusoid[-2], skill_levels[-1] - skill_levels[-2], sinusoid[-1] - sinusoid[-2],
          color='purple', length_includes_head=True, head_width=0.15, head_length=0.3)

# Set plot labels and title
plt.xlabel('Skill-level', fontsize=18)
plt.ylabel('Challenge-level', rotation='vertical', fontsize=18)

# Set plot limits and grid
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.grid(True)

# Set tick labels
tick_labels = ['0', '2', '4', '6', '8', '10']
plt.xticks(np.linspace(0, 10, 6), tick_labels)
plt.yticks(np.linspace(0, 10, 6), tick_labels)

# Add text annotations to label the areas without shaded background
plt.text(1, 6, 'Voir', color='black', ha='center', va='center', fontsize=50)
plt.text(4.5, 4.7, 'Pouvoir', color='black', ha='center', va='center', fontsize=50)
plt.text(8, 3, 'Savoir', color='black', ha='center', va='center', fontsize=50)

# Display the plot
plt.show()

# %% [markdown]
# 1. <span style="color:lightpink;">Voir</span>
#    - Truth: Perception of biological and primal stimuli; see
#    - Entirely dependent on perspective; power/hierarchy
#    - Cells/Tissues; Immune/Neuro/Endocrine/Reproductive/Kidney/CVS
#    - Steroids, Catecholamines, Cytokines, Hormones
#    - Dionysian: Homeostasis, Biology
# 2. <span style="color:lightyellow;">Pouvoir</span>
#    - Knowledge: Acquiring skills, match challenges; do
#    - Adaptation, homeostasis, allostasis; variance/explain
#    - Organs/Systems; Muscle/Bone
#    - Dopamine, Serotonin, Oxytocin, Endorphins
#    - Tragedy: Allostasis, Psychology
# 3. <span style="color:lightgreen;">Savoir</span>
#    - Justice: Cumulated values, beliefs, and norms; be
#    - Silos, numbing with comforts and distractions, "bread"; bias/control
#    - Person/Interaction; Frontal Cortex, Hippocampus, Amygdala
#    - GABA, Adenosine, Glutamate, Acetylcholine
#    - Apollonian: Sociostasis, Credo
#
#
# </Details>
#
# <Details>
#    <Summary></Summary>
#
# 1. [This](https://www.economist.com/films/2023/10/09/well-red-inside-the-economists-language-and-style) reveals a lot of interesting phenomena
# 2. Souless GenZ and Millenials
# 3. Exposed to the same "Dionysian" stimuli
# 4. With a much weakened "Apollonian" counterbalance
# 5. History usually provided monumental, antiquarian, and critical perspectives
# 6. Now, it's just a "Dionysian" free-for-all - and with all the attendant fenzy, intoxication and addiction
# 7. Because frenzy is from the external (boundless) rather than internal (bounded) elements, we fear it breaches the limits of the "Apollonian" counterbalance
# </Details>
